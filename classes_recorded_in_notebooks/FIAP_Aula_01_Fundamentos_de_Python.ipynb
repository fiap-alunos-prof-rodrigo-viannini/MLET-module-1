# %% [markdown]
# # Bem vindos e bem vindas a disciplina de Python para ML e IA

# %% [markdown]
# ## O Professor
#
# #### Rodrigo Araujo Viannini
# - Graduado em Engenharia de Produção - La Salle - RJ<br />
# - Mestrando em IA na COPPE-UFRJ
# - Professor na POS TECH | FIAP
# - Engenheiro de Inteligência Artificial da MJV Technology & Innovation

# %% [markdown]
# ## Tópicos da aula
# <br>
#
# - Varíaveis: Armazenamento de dados;
# - Operadores;
# - Condicionais;
# - Listas, Tuplas e Dicionários;
# - Laços de repetição;
# - Funções.

# %% [markdown]
# ## Varíaveis: Armazenamento de dados <a class="anchor" id="tres"></a>
#
# &emsp; Váriaveis como o próprio diz são "coisas" variáveis, e usaremos elas para armazenar nossos dados.<br>
#
# &emsp; Dados possuem tipos: **_string_** que armazena texto, **_int_** que armazena números inteiros, **_float_** que armazena números decimais (separados por ponto!), e **_boolean_** que armazenará _true_ ou _false_. Embora o Python faça o trabalho de saber o que é o que sozinho, você precisa entender os tipos de dados para trabalhar com eles.<br>

# %% [markdown]
# String

# %%
# Entre aspas simples ou duiplas, podem adicionar qualquer tipo de dado
textoString = 'Olá Mundo!'
print(textoString)
# Out:
# Olá Mundo!

# %%
textoString = "Olá Mundo!"
print(textoString)
# Out:
# Olá Mundo!

# %%
string_ = "012345 um texto QUALQUER, !@#$% True ou False!"
print(string_)
print(type(string_))
# Out:
# 012345 um texto QUALQUER, !@#$% True ou False!
# <class 'str'>

# %% [markdown]
# Numeros inteiros

# %%
numeroInteiro = 3
print(numeroInteiro)
print(type(numeroInteiro))
# Out:
# 3
# <class 'int'>

# %% [markdown]
# Numeros decimais ou float

# %%
numeroDecimal = 8.32
print(numeroDecimal)
print(type(numeroDecimal))
# Out:
# 8.32
# <class 'float'>

# %% [markdown]
# Boleanos

# %%
booleanoVerdadeiro = True
print(booleanoVerdadeiro)
print(type(booleanoVerdadeiro))
# Out:
# True
# <class 'bool'>

# %% [markdown]
#  -- ATENÇÃO --
#
# - Sempre tente usar nomes que façam sentidos no seu programa para não se atrapalharem, isso fará mais sentido nos exercícios.
#
#
# - No Python podemos definir muitas variáveis numa mesma linha com valores diferentes ou o mesmo valor.

# %%
# As variáveis serão atribuidas respectivamente
Nome, Idade, Nota = "Pedro", 12, 7.5
print("Olá,", Nome, ", você tem", Idade, "anos e tirou:", Nota, "na prova")
# Out:
# Olá, Pedro , você tem 12 anos e tirou: 7.5 na prova

# %%
# Todas serão iguais a 0
x = y = z = 0
print("x=", x, "; y=", y, "; z=", z)
# Out:
# x= 0 ; y= 0 ; z= 0

# %% [markdown]
# ## Operadores Matemáticos e Comunicação com o Usuário <a class="anchor" id="quatro"></a>
#
# ### Operadores Matemáticos
#
# &emsp; O Python faz operações matemáticas entre variáveis e dados puros, a seguir temos uma tabela com os operadores e suas funções:<br>
#
# | Operador | Função           |
# |----------|------------------|
# | +        | Adição           |
# | -        | Subtração        |
# | *        | Multiplicação    |
# | /        | Divisão          |
# | %        | Resto de divisão |
# | **       | Potênciação      |
# | //       | Divisão Inteira  |
#
# &emsp;

# %% [markdown]
# Adição

# %%
num1 = 4
num2 = 3.5
adicao = num1 + num2
print(adicao)
# Out:
# 7.5

# %% [markdown]
# Subtração

# %%
num1 = 4
num2 = 3
subtracao = num1 - num2
print(subtracao)
# Out:
# 1

# %% [markdown]
# Multiplicação

# %%
num1 = 2
num2 = 2
multiplicacao = num1 * num2
print(multiplicacao)
# Out:
# 4

# %% [markdown]
# Divisao

# %%
num1 = 4
num2 = 2
divisao = num1 / num2
print(divisao)
# Out:
# 2.0

# %% [markdown]
# Resto da divisao

# %%
num1 = 5
num2 = 2
resto = num1 % num2
print(resto)
# Out:
# 1

# %% [markdown]
# Divisao inteira

# %%
num1 = 5
num2 = 2

# Divisao convencional
divisao_conv = num1 / num2
print(divisao_conv) # decimal
print(type(divisao_conv))

# Divisao inteira
divisao_inteira = num1 // num2
print(divisao_inteira) # inteiro
print(type(divisao_inteira))
# Out:
# 2.5
# <class 'float'>
# 2
# <class 'int'>

# %% [markdown]
# Potenciação

# %%
num1 = 2
num2 = 3
potenciacao = num1 ** num2
print(potenciacao)
# Out:
# 8

# %% [markdown]
# Além disso, fazemos uso de parênteses para definir ordem de contas assim como na matemática.<br>

# %%
expressao = ((3 + 2) - 1) * 8 / 10 # a = 3.2
print("resultado da expressao =", expressao)
# Out:
# resultado da expressao = 3.2

# %% [markdown]
# ```
# # Isto` está formatado como código`
# ```
#
# ### input() e print()
#
# &emsp; A funcão input() irá ler uma entrada de usuário em formato de _string_ (portanto se você espera outro tipo de dado deverá fazer o _cast_), e podemos colocar outra _string_ dentro dos parênteses que será a pergunta feita ao usuário.<br>
# &emsp; A funcão print() irá imprimir algo para o usuário, e receberá o que ela deve imprimir dentro dos parênteses, podendo ser variáveis, textos e a mistura dos dois.<br>

# %%
nome = input("Qual seu nome? ")
print("Bom dia,", nome)
# Out:
# Qual seu nome? Rodrigo
# Bom dia, Rodrigo

# %%
idade = int(input("Qual sua idade? "))
print("Você tem", idade, "anos")
# Out:
# Qual sua idade? 40
# Você tem 40 anos

# %%
peso = float(input("Qual seu peso? "))
print("Você tem", peso, "kg")
# Out:
# Qual seu peso? 93
# Você tem 93.0 kg

# %%
# Agora, vamos concatenar o nome e a idade e exibir a mensagem
mensagem = nome + " tem " + str(idade) + " anos e possui " + str(peso) + " kg"
print(mensagem)
# Out:
# Rodrigo tem 40 anos e possui 93.0 kg

# %%
# Agora, vamos concatenar o nome e a idade e exibir a mensagem
mensagem = f'{nome} tem {idade} anos e possui {str(peso)} kg'
print(mensagem)
print(type(mensagem))
# Out:
# Rodrigo tem 40 anos e possui 93.0 kg
# <class 'str'>

# %% [markdown]
# ## Operadores lógicos de comparação
#
# Em muitos problemas de programação, há necessidade de se fazer **comparações** entre variáveis.
#
# Por exemplo:
#
# - checar se um número é maior que outro;
# - checar se uma variável é igual a outra;
# - checar se há números diferentes; etc.
#
# Para fazer essas comparações, utilizamos os **operadores lógicos de comparação**. Em Python, há 6 desses operadores:
#
# - Maior que: >
# - Maior ou igual: >=
# - Menor que: <
# - Menor ou igual: <=
# - Igual: ==
# - Diferente: !=
#
# O resultado de uma comparação sempre vai ser um booleano, isto é, **True** ou **False**!
#
# Dica: sempre leia as comparações como uma **pergunta**
#
# - Ex: "numero < 100", leia: "o valor na variável numero é menor que 100?"
#
# Os operadores de comparação são destacados em **roxo** no Jupyter

# %% [markdown]
# ## Numericos

# %%
# Definindo duas variáveis para comparação
numero1 = 75
numero2 = 100

# %% [markdown]
# Checar se um número é maior que outro

# %%
maior_que = numero1 > numero2
print(f"É {numero1} maior que {numero2}? {maior_que}")
# Out:
# É 75 maior que 100? False

# %% [markdown]
# Checar se um número é maior ou igual a outro

# %%
maior_ou_igual = numero1 >= numero2
print(f"É {numero1} maior ou igual a {numero2}? {maior_ou_igual}")
# Out:
# É 75 maior ou igual a 100? False

# %% [markdown]
# Checar se um número é menor que outro

# %%
menor_que = numero1 < numero2
print(f"É {numero1} menor que {numero2}? {menor_que}")
# Out:
# É 75 menor que 100? True

# %% [markdown]
# Checar se um número é menor ou igual a outro

# %%
menor_ou_igual = numero1 <= numero2
print(f"É {numero1} menor ou igual a {numero2}? {menor_ou_igual}")
# Out:
# É 75 menor ou igual a 100? True

# %% [markdown]
# Checar se um número é igual a outro

# %%
igual = numero1 == numero2
print(f"É {numero1} igual a {numero2}? {igual}")
# Out:
# É 75 igual a 100? False

# %% [markdown]
# Checar se um número é diferente de outro

# %%
diferente = numero1 != numero2
print(f"É {numero1} diferente de {numero2}? {diferente}")
# Out:
# É 75 diferente de 100? True

# %% [markdown]
# ## Strings

# %%
# Definindo duas strings para comparação
string1 = "python"
string2 = "java"

# %% [markdown]
# Checar se uma string é maior que outra (ordem lexicográfica)

# %%
maior_que_str = string1 > string2
print(f"A string '{string1}' é maior que '{string2}'? {maior_que_str}")
# Out:
# A string 'python' é maior que 'java'? True

# %% [markdown]
# Checar se uma string é maior ou igual a outra

# %%
maior_ou_igual_str = string1 >= string2
print(f"A string '{string1}' é maior ou igual a '{string2}'? {maior_ou_igual_str}")
# Out:
# A string 'python' é maior ou igual a 'java'? True

# %% [markdown]
# Checar se uma string é menor que outra (ordem lexicográfica)

# %%
menor_que_str = string1 < string2
print(f"A string '{string1}' é menor que '{string2}'? {menor_que_str}")
# Out:
# A string 'python' é menor que 'java'? False

# %% [markdown]
# Checar se uma string é menor ou igual a outra

# %%
menor_ou_igual_str = string1 <= string2
print(f"A string '{string1}' é menor ou igual a '{string2}'? {menor_ou_igual_str}")
# Out:
# A string 'python' é menor ou igual a 'java'? False

# %% [markdown]
# Checar se uma string é igual a outra

# %%
igual_str = string1 == string2
print(f"A string '{string1}' é igual a '{string2}'? {igual_str}")
# Out:
# A string 'python' é igual a 'java'? False

# %% [markdown]
# Checar se uma string é diferente de outra

# %%
diferente_str = string1 != string2
print(f"A string '{string1}' é diferente de '{string2}'? {diferente_str}")
# Out:
# A string 'python' é diferente de 'java'? True

# %% [markdown]
# ## Boleanos

# %%
# Definindo dois booleanos para comparação
booleano1 = True
booleano2 = False

# %% [markdown]
# Checar se um booleano é igual a outro

# %%
igual_bool = booleano1 == booleano2
print(f"O booleano {booleano1} é igual a {booleano2}? {igual_bool}")
# Out:
# O booleano True é igual a False? False

# %% [markdown]
# Checar se um booleano é diferente de outro

# %%
diferente_bool = booleano1 != booleano2
print(f"O booleano {booleano1} é diferente de {booleano2}? {diferente_bool}")
# Out:
# O booleano True é diferente de False? True

# %% [markdown]
# ## Operadores lógicos de conjunção
#
# Além dos operadores lógicos de comparação, também temos os **operadores lógicos de conjunção**, que são utilizados pra fazer uma **combinação** entre comparações.
#
# Os operadores de conjunção são: **and** e **or**, e eles seguem a seguinte regra:
#
# - **and** só é True se **ambas** as comparações forem True:
#     - False and True resulta em "False"
#     - False and False resulta em "False"
#     - True and True resulta em "True"
# - **or** é True se **pelo menos uma** das comparações for True:
#     - False or True resulta em "True"
#     - True or True resulta em "True"
#     - False or False resulta em "False"
#
# Os operadores de conjunção são destacados em **verde escuro** no Jupyter

# %%
2 < 5
# Out:
# True

# %%
2 == 5
# Out:
# False

# %%
# True or False, resulta em True
(2 < 5) or (2 == 5)
# Out:
# True

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# True or False, resulta em False
(2 < 5) and (2 == 5)
# Out:
# False

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# OBS: Se tivermos mais de duas comparações pra fazer conjunção, é melhor usarmos parênteses.

# %% [markdown]
# Curiosidade: Tabela verdade!!!

# %%
import itertools     # utilizadas em construções de código que envolvem loops e iterações.
import pandas as pd  # estruturas de dados no Pandas são o DataFrame e a Series.

# Função para gerar a tabela verdade
def tabela_verdade(variaveis, expressao):
    # Gera todas as combinações possíveis de valores booleanos para as variáveis
    combinacoes = list(itertools.product([False, True], repeat=len(variaveis)))

    # Calcula os resultados da expressão para cada combinação
    resultados = [expressao(*comb) for comb in combinacoes]

    # Cria um DataFrame com os resultados
    df = pd.DataFrame(combinacoes, columns=variaveis)
    df['Resultado'] = resultados

    return df


# Variáveis para o operador AND
variaveis_and = ['A', 'B']

# Variáveis para o operador OR
variaveis_or = ['A', 'B']

# Expressões lógicas para o operador AND e OR
def and_operacao(A, B):
    return A and B

def or_operacao(A, B):
    return A or B

# Criação e exibição das tabelas verdade
print("Tabela Verdade para A and B:")
print(tabela_verdade(variaveis_and, and_operacao))
print("\nTabela Verdade para A or B:")
print(tabela_verdade(variaveis_or, or_operacao))
# Out:
# Tabela Verdade para A and B:
#        A      B  Resultado
# 0  False  False      False
# 1  False   True      False
# 2   True  False      False
# 3   True   True       True
#
# Tabela Verdade para A or B:
#        A      B  Resultado
# 0  False  False      False
# 1  False   True       True
# 2   True  False       True
# 3   True   True       True

# %% [markdown]
# ## Inversão de Operadores Lógicos
#
# Além de tudo que vimos temos também o operador _not_ que literalmente nega uma expressão, ou seja, se o resultado fosse true se torna false, e se false se torna true, isso serve para facilitar a lógica em cima de algumas expressões, quando você quer testar algo e rodar um pedaço de código quando a expressão **não** é satisfeita

# %%
a = 10
b = 5
print(not(a > b))
# Out:
# False

# %% [markdown]
# A inversão pode ser feita sem o uso do _not_, e é interessante aprender como fazer isso, pois assim dominaremos por completo os operadores lógicos.
# Observe a que a lógica de inversão consiste em entender os opostos dos operadores, aqui estão alguns exemplos para você entender:
#
# | Operador | Operador Invertido |
# |----------|--------------------|
# | ==       | !=                 |
# | >        | <=                 |
# | <        | >=                 |
#
# Simples não? Vamos testar

# %%
a = 10
print(a > 10)
print(not(a > 10))
print(a <= 10)
# Out:
# False
# True
# True

# %% [markdown]
# ## Condicionais (If)
# O condicional If tem a seguinte estrutura
#
#
#     if condicao:
#         # código a ser executado se a condição for satisfeita

# %% [markdown]
# Note que seu programa vai seguir um fluxo linha a linha e na condicional haverá um possível **desvio de fluxo**, isto é, caso a condição não seja satisfeita o código pula tudo que esta dentro do if, e o que está dentro do if? Tudo aquilo que está na **identação** do if, ou seja, está um _tab_ mais a frente que o if.

# %%
a = 10
b = 5

if a > b:
    print("'a' maior que 'b'")
print("Fim")
# Out:
# 'a' maior que 'b'
# Fim

# %% [markdown]
# ## Condicionais (Elif)
# O _elif_ deve ser lido com **se não**, portanto ele será uma nova condição que será testada **caso a condição do if (ou outros elifs acima) NÃO seja satisfeita**, e sua estrutura é a seguinte:
#
#     if condicao:
#         # codigo caso if seja satisfeito
#     elif condicaoElif:
#         # codigo caso elif satisfeito
#     elif condicaoElif2:
#         # codigo caso elif2 satisfeito
#     elif condicaoElif3:
#         # codigo caso elif3 satisfeito

# %% [markdown]
# Note que podemos ter de 0 a N _elifs_, e seu código seguirá uma ordem de conferir as condições uma a uma até que uma seja satisfeita, seu código executa **e todo o resto do bloco de if elif será ignorado**. Note também que caso nenhuma condição seja satisfeita nada dentro do if e elifs é executado e o código "passa reto".

# %%
a = 6

if a > 10:
    print("'a' maior que 10")
elif 7 < a:
    print("'a' entre 7 e 10")
elif 3 < a:
    print("'a' entre 3 e 7")
elif 0 <= a:
    print("'a' entre 0 e 3")

print("Fim")
# Out:
# 'a' entre 3 e 7
# Fim

# %% [markdown]
# ## Condicionais (Else)
#
# O else deve ser lido como um **então ou caso contrário**, ele, diferente dos exemplos acima, não tem uma condiçao, ele será colocado ao fim do bloco if e será executado **quando todas as condições anteriores forem insatisfeitas**, a estrutura com else fica da seguinte maneira:
#
#
#     if condicao:
#         # codigo caso if seja satisfeito
#     elif condicaoElif:
#         # codigo caso elif satisfeito
#     else:
#         # codigo caso if e elif insatisfeito
#
# OU
#
#     if condicao:
#         # codigo caso if seja satisfeito
#     else:
#         # codigo caso if insatisfeito

# %% [markdown]
# Note que no contexto de _if else_ os _elifs_ são opcionais, portanto um bloco completo de _if_ pode possuir de 0 a N _elifs_ entre o _if_ e o _else_.

# %%
# Para chegar no "else" preciso de qualquer valor negativo
a = -10

if a > 10:
    print("'a' maior que 10")
elif 7 < a <= 10:
    print("'a' entre +7 e 10")
elif 3 < a <= 7:
    print("'a' entre +3 e 7")
elif 0 < a <= 3:
    print("'a' entre +0 e 3")
else:
    print("'a' é menor ou igual a 0")

print("Fim")
# Out:
# 'a' é menor ou igual a 0
# Fim

# %% [markdown]
# ### Condicional Aninhada
#
# Dentro de um _if, elif ou else_ podemos ter outros blocos de _ifs_ o que chamamos de aninhamento, isto pode ser feito para facilitar leitura de código ou mesmo para validar uma segunda condição que afeitaria pouco o código da primeira, veja o exemplo:

# %%
nome = input("Digite seu nome: ")
idade = int(input("Digite sua idade: "))

if idade >= 18:
    habilitado = input("Você tem habilitação? (S/N): ")
    if habilitado == "S":
        print("Olá,", nome, "você tem", idade, "anos e pode dirigir")
    else:
        print("Olá,", nome, "você tem", idade, "anos mas não pode dirigir")
else:
    print("Olá,", nome, "você é menor de idade, portanto, não pode dirigir.")
# Out:
# Digite seu nome: Rodrigo
# Digite sua idade: 40
# Você tem habilitação? (S/N): s
# Olá, Rodrigo você tem 40 anos mas não pode dirigir

# %% [markdown]
# ##  Listas, Tuplas e Dicionários
#
#  Nestas estruturas de dados, você poderá armazenar e organizar informações de maneiras diferentes. Vamos explorar cada uma delas para entender suas características, operações e quando utilizá-las.

# %% [markdown]
# ### Listas:
#
# As listas em Python são sequências ordenadas e mutáveis de itens. Cada item pode ser de qualquer tipo, e você pode acessar os elementos por índice.

# %% [markdown]
# Exemplo 1: Criando uma Lista e Acessando Elementos por Índice

# %%
# Criando uma lista vazia
lista_vazia = []

# %%
print(lista_vazia)
# Out:
# []

# %%
type(lista_vazia)
# Out:
# list

# %%
# Criando uma lista heterogênea
elementos_variados = ["Python", 42, 3.14, True] # Python: 0 ate n

# Acessando elementos por índice
primeiro_elemento = elementos_variados[0]
ultimo_elemento = elementos_variados[3]

print("Primeiro elemento:", primeiro_elemento)
print("Segundo elemento:", ultimo_elemento)
# Out:
# Primeiro elemento: Python
# Segundo elemento: True

# %%
# Criando uma lista heterogênea
elementos_variados = ["Python", 42, 3.14, True] # Python: 0 ate n

# Acessando elementos por índice
primeiro_elemento = elementos_variados[0]
ultimo_elemento = elementos_variados[-1]

print("Primeiro elemento:", primeiro_elemento)
print("Segundo elemento:", ultimo_elemento)
# Out:
# Primeiro elemento: Python
# Segundo elemento: True

# %% [markdown]
# Exemplo 2: Adicionando e Removendo Elementos com append:

# %%
# Adicionando um elemento ao final da lista usando append
elementos_variados.append("Novo Elemento")

# Removendo um elemento da lista
elementos_variados.remove(42)

print("Lista após adição e remoção:", elementos_variados)
# Out:
# Lista após adição e remoção: ['Python', 3.14, True, 'Novo Elemento']

# %% [markdown]
# Exemplo 3: Tamanho da Lista e Iteração

# %%
# Obtendo o tamanho da lista
tamanho_lista = len(elementos_variados)
print("Tamanho da lista:", tamanho_lista)
# Out:
# Tamanho da lista: 4

# %%
# Iterando sobre a lista e imprimindo cada elemento
print("Elementos na lista:")
for elemento in elementos_variados:
    print(elemento)
# Out:
# Elementos na lista:
# Python
# 3.14
# True
# Novo Elemento

# %% [markdown]
# LIST COMPREHENSION
#
#
# Uma compreensão de lista é uma maneira concisa de criar listas em uma única linha.

# %%
elementos_variados = ['Python', 3.14, True, 'Novo Elemento']

# List comprehension para imprimir cada elemento da lista
[print(elemento) for elemento in elementos_variados]
# Out:
# Python
# 3.14
# True
# Novo Elemento
# [None, None, None, None]

# %% [markdown]
# OBS: A razão pela qual você está vendo a lista [None, None, None, None] é porque a list comprehension está sendo usada para criar uma lista de valores None, pois a expressão dentro da list comprehension (o print(elemento)) retorna implicitamente None.

# %%
# Criando uma lista usando compreensão
numeros_quadrado_lista = [x**2 for x in range(5)] # range == 0,1,2,3,4
numeros_quadrado_lista
# Out:
# [0, 1, 4, 9, 16]

# %% [markdown]
# ### TUPLA

# %% [markdown]
# Exemplo 1: Criando uma Tupla e Acessando Elementos por Índice:

# %%
# Criando um tupla vazia
tupla_vazia = ()

# %%
print(tupla_vazia)
# Out:
# ()

# %%
type(tupla_vazia)
# Out:
# tuple

# %%
# Criando uma tupla heterogênea
elementos_variados_tupla = ("Python", 42, 3.14, True)

# Acessando elementos por índice
primeiro_elemento = elementos_variados_tupla[0]
segundo_elemento = elementos_variados_tupla[1]

print("Primeiro elemento:", primeiro_elemento)
print("Segundo elemento:", segundo_elemento)
# Out:
# Primeiro elemento: Python
# Segundo elemento: 42

# %% [markdown]
# Exemplo 2: Imutabilidade das Tuplas:

# %%
# Tentativa de adicionar um elemento à tupla (resultará em erro)
# elementos_variados_tupla.append("Novo Elemento")

# Tentativa de modificar um elemento da tupla (resultará em erro)
# elementos_variados_tupla[1] = 99

# %% [markdown]
# Exemplo 3: Tamanho da Tupla e Iteração:

# %%
# Obtendo o tamanho da tupla
tamanho_tupla = len(elementos_variados_tupla)

print("Tamanho da tupla de frutas:", tamanho_tupla)

# Iterando sobre a tupla e imprimindo cada elemento
print("Frutas na tupla:")
for fruta in elementos_variados_tupla:
    print(fruta)
# Out:
# Tamanho da tupla de frutas: 4
# Frutas na tupla:
# Python
# 42
# 3.14
# True

# %% [markdown]
# ### DICIONARIOS

# %% [markdown]
# Exemplo 1: Criando Dicionários:

# %%
# Criando um dicionário vazio
dicionario_vazio = {}

# %%
print(dicionario_vazio)
# Out:
# {}

# %%
type(dicionario_vazio)
# Out:
# dict

# %%
# Criando um dicionário com pares chave-valor
aluno = {
    "nome": "Ana",
    "idade": 22,
    "curso": "Machine Learning Engineering",
    "instituição": "FIAP"
}

# %%
print(aluno)
# Out:
# {'nome': 'Ana', 'idade': 22, 'curso': 'Machine Learning Engineering', 'instituição': 'FIAP'}

# %% [markdown]
# Exemplo 2: Acessando Elementos por Chave:

# %%
# Acessando elementos por chave
nome_aluno = aluno["nome"]
instituicao_aluno = aluno["instituição"]

print("Nome do aluno:", nome_aluno)
print("instituição:", instituicao_aluno)
# Out:
# Nome do aluno: Ana
# instituição: FIAP

# %% [markdown]
# Exemplo 3: Adicionando e Removendo Elementos:

# %%
aluno
# Out:
# {'nome': 'Ana',
#  'idade': 22,
#  'curso': 'Machine Learning Engineering',
#  'instituição': 'FIAP'}

# %%
# Adicionando um novo par chave-valor
aluno["disciplina"] = "Python para ML e IA"
aluno["nota"] = 9.5

# %%
aluno
# Out:
# {'nome': 'Ana',
#  'idade': 22,
#  'curso': 'Machine Learning Engineering',
#  'instituição': 'FIAP',
#  'disciplina': 'Python para ML e IA',
#  'nota': 9.5}

# %%
# Removendo um elemento do dicionário
del aluno["idade"]

# %%
aluno
# Out:
# {'nome': 'Ana',
#  'curso': 'Machine Learning Engineering',
#  'instituição': 'FIAP',
#  'disciplina': 'Python para ML e IA',
#  'nota': 9.5}

# %% [markdown]
# Exemplo 4: Verificando Existência de Chaves:

# %%
# Verificando existência de chave
tem_curso = "curso" in aluno
tem_altura = "altura" in aluno

print("Tem chave 'curso'?", tem_curso)
print("Tem chave 'altura'?", tem_altura)
# Out:
# Tem chave 'curso'? True
# Tem chave 'altura'? False

# %% [markdown]
# Exemplo 5: Chaves e Valores:

# %%
# Obtendo todas as chaves e valores
chaves = aluno.keys()
valores = aluno.values()

print("Chaves do dicionário:", chaves)
print("Valores do dicionário:", valores)
# Out:
# Chaves do dicionário: dict_keys(['nome', 'curso', 'instituição', 'disciplina', 'nota'])
# Valores do dicionário: dict_values(['Ana', 'Machine Learning Engineering', 'FIAP', 'Python para ML e IA', 9.5])

# %% [markdown]
# ### Existem outas funcionalidades que fazem os dicionários serem extremamente usuais para os desenvolvedores:

# %% [markdown]
# #### ITERAÇÃO
#
# items() retorna uma visão de pares chave-valor, permitindo a iteração simultânea sobre chaves e valores.

# %%
# Iterando sobre chaves e valores simultaneamente
for chave, valor in aluno.items():
    print(f"{chave}: {valor}")
# Out:
# nome: Ana
# curso: Machine Learning Engineering
# instituição: FIAP
# disciplina: Python para ML e IA
# nota: 9.5

# %% [markdown]
# #### OBTENDO UM VALOR COM UM PADRÂO
#
# get(chave, padrão) retorna o valor associado à chave, ou o valor padrão se a chave não existir.

# %%
# Obtendo um valor com um padrão se a chave não existir
pesquisa_get = aluno.get("instituição")
pesquisa_get
# Out:
# 'FIAP'

# %% [markdown]
# #### MÉTODO POP
#
# pop(chave) remove a chave do dicionário e retorna seu valor associado.

# %%
# Removendo e obtendo o valor associado a uma chave
nota_aluno = aluno.pop("nota")
aluno
# Out:
# {'nome': 'Ana',
#  'curso': 'Machine Learning Engineering',
#  'instituição': 'FIAP',
#  'disciplina': 'Python para ML e IA'}

# %% [markdown]
# #### MÉTODO UPDATE
#
# update(outro_dicionario) adiciona os pares chave-valor de outro_dicionario ao dicionário existente.

# %%
# Atualizando o dicionário com novos pares chave-valor
aluno.update(
    {
        "altura": 1.75,
        "skill": "Proeficiência em Python"
     }
    )
aluno
# Out:
# {'nome': 'Ana',
#  'curso': 'Machine Learning Engineering',
#  'instituição': 'FIAP',
#  'disciplina': 'Python para ML e IA',
#  'altura': 1.75,
#  'skill': 'Proeficiência em Python'}

# %% [markdown]
# #### DICT COMPREHENSION
#
# Uma compreensão de dicionário é uma maneira concisa de criar dicionários em uma única linha.

# %%
# Criando um dicionário usando compreensão
numeros_quadrado = {x: x**2 for x in range(5)}
numeros_quadrado
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}

# %% [markdown]
# ## Laços de repetição (while)
#
# Uma das utilidades de linguagens de programação é a de automatizar tarefas que são repetitivas.
#
# Mas, pra isso ser viável, seria bom se tivéssemos uma estrutura para **repetir comandos**, não é mesmo?
#
# Imagine que eu queira exibir na tela "Olá, mundo!" 5 vezes. Podemos fazer:

# %%
print("Olá, mundo!")
print("Olá, mundo!")
print("Olá, mundo!")
print("Olá, mundo!")
print("Olá, mundo!")
# Out:
# Olá, mundo!
# Olá, mundo!
# Olá, mundo!
# Olá, mundo!
# Olá, mundo!

# %% [markdown]
# Mas, e se eu quiser exibir essa mensagem 1000 vezes? Ou 1 milhão de vezes? Não é ideal escrevermos o mesmo pedaço de código tantas vezes, né?
#
# Para isso, existem os **laços de repetição**, que permitem repetir pedaços de código quantas vezes desejarmos!
#
# O primeiro laço que vamos ver é o **while**. Este laço tem a seguinte estrutura:
#
# ```python
# while (condicao é True):
#     operacao_repetida
# ```
#
# Ou seja, o que tá no bloco do while é repetido **enquanto a condição for verdadeira**

# %% [markdown]
# Isso pode levar a **loops infinitos**

# %%
# Repetido enquanto a condição for verdadeira!
while 2==2: # Sempre será verdadeira, portanto, laço infinito
    print("Olá, mundo")
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-237-64817fd8ba4a> in <cell line: 2>()
#       1 # Repetido enquanto a condição for verdadeira!
#       2 while 2==2: # Sempre será verdadeira, portanto, laço infinito
# ----> 3     print("Olá, mundo")
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py in schedule(self, f)
#     198         If the thread is not running, call immediately.
#     199         """
# --> 200         if self.thread.is_alive():
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
#
# /usr/lib/python3.10/threading.py in is_alive(self)
#    1176         """
#    1177         assert self._initialized, "Thread.__init__() not called"
# -> 1178         if self._is_stopped or not self._started.is_set():
#    1179             return False
#    1180         self._wait_for_tstate_lock(False)
#
# KeyboardInterrupt:

# %% [markdown]
# Para que loops infinitos não aconteçam, temos que fazer uma **atualização da condição** a cada iteração do laço!
#
# Isso é, temos que **atualizar** a variavel que contabiliza as repetições no loop

# %% [markdown]
# Assim, o que fazemos é **definir a condição do while em termos de uma variável que tenha seu valor atualizado!**
#
# Para isso, é comum nos referirmos à variàvel da condição como **variável contadora**.
#
# Para atualizar a variável contadora dentro do while, em geral a atualizamos em +1

# %%
cont = 0

while cont < 5: # considera o 4 por ser excludente: cont < 5 é igual cont < (5-1)
    print("Olá mundo")
    cont = cont + 1 # cont += 1
# Out:
# Olá mundo
# Olá mundo
# Olá mundo
# Olá mundo
# Olá mundo

# %% [markdown]
# Vamos entender um pouco melhor como a variável contadora se comporta?
#
# Pra isso, basta exibi-la a cada iteração:

# %% [markdown]
# O código acima equivale a:

# %%
# inicialmente, a variavel cont vale 0

# pegamos o valor anterior (0) e somamos 1, ficando 1

# pegamos o valor anterior (1) e somamos 1, ficando 2

# pegamos o valor anterior (2) e somamos 1, ficando 3

# pegamos o valor anterior (3) e somamos 1, ficando 4

# %% [markdown]
# Usar a condição com < ao invés de != em geral garante maior segurança ao seu algoritmo, pois evita imprevistos caso você receba números do usuário!

# %% [markdown]
# Podemos também atualizar a condição de repetição segundo informado pelo usuário
#
# Esse uso é bem importante para **garantir que o usuário digitou corretamente o que foi solicitado**
#
# Por exemplo, vamos pedir pro usuário digitar um número maior que 10. **Enquanto ele não fizer o que queremos**, vamos continuar pedindo pra ele digitar um novo valor:

# %%
numero = 0

# Enquanto o numero for menor que 10:
while numero <= 10:
    # Conntinua executando essa ação
    numero = int(input("Digite um numero maior que 10: "))

# Só será impresso o valor digitado na tela, quando o valor digitado não mais atender a condição.
print("O numero digitado foi: ", numero)
# Out:
# Digite um numero maior que 10: 7
# Digite um numero maior que 10: 4
# Digite um numero maior que 10: 9
# Digite um numero maior que 10: 10
# Digite um numero maior que 10: 11
# O numero digitado foi:  11

# %% [markdown]
# ### break, continue e else
#
# O while pode ser parado no meio com o break, isso é utilizado caso exista algum(ns) casos excepcionais onde seu código deve parar ou mesmo para poupar processamento em um loop que já fez o que precisava e usava a condição inicial apenas como limite de iterações.

# %% [markdown]
# BREAK

# %%
contador = 0  # Inicializa o contador em 0

while contador < 10:  # Inicia um loop while que continua enquanto o contador for menor que 10
    print(f"Contador: {contador}")  # Imprime o valor atual do contador
    contador += 1  # Incrementa o contador em 1

    if contador == 5:
        print("Encontrou o número 5! Vamos parar o loop.")
        break  # Se o contador atingir 5, encerra o loop imediatamente com a instrução break

print("Fim do programa.")
# Out:
# Contador: 0
# Contador: 1
# Contador: 2
# Contador: 3
# Contador: 4
# Encontrou o número 5! Vamos parar o loop.
# Fim do programa.

# %% [markdown]
# CONTINUE

# %%
contador = 0  # Inicializa o contador em 0

while contador < 10:  # Inicia um loop while que continua enquanto o contador for menor que 10
    print(f"Contador: {contador}")  # Imprime o valor atual do contador
    contador += 1  # Incrementa o contador em 1

    if contador == 5:
        print("Encontrou o número 5! Vamos continuar o loop.")
        continue  # Se o contador atingir 5, encerra o loop imediatamente com a instrução break

print("Fim do programa.")
# Out:
# Contador: 0
# Contador: 1
# Contador: 2
# Contador: 3
# Contador: 4
# Encontrou o número 5! Vamos continuar o loop.
# Contador: 5
# Contador: 6
# Contador: 7
# Contador: 8
# Contador: 9
# Fim do programa.

# %%
contador = 0  # Inicializa o contador em 0

while contador < 10:  # Inicia um loop while que continua enquanto o contador for menor que 10
    print(f"Contador: {contador}")  # Imprime o valor atual do contador
    contador += 1  # Incrementa o contador em 1

    if contador % 2 == 0:
        print("Número par encontrado. Vamos pular para a próxima iteração.")
        continue  # Se o contador for par, pula para a próxima iteração sem executar o restante do código no loop

print("Fim do programa.")
# Out:
# Contador: 0
# Contador: 1
# Número par encontrado. Vamos pular para a próxima iteração.
# Contador: 2
# Contador: 3
# Número par encontrado. Vamos pular para a próxima iteração.
# Contador: 4
# Contador: 5
# Número par encontrado. Vamos pular para a próxima iteração.
# Contador: 6
# Contador: 7
# Número par encontrado. Vamos pular para a próxima iteração.
# Contador: 8
# Contador: 9
# Número par encontrado. Vamos pular para a próxima iteração.
# Fim do programa.

# %% [markdown]
# USO DO "ELSE" NO "LOOP WHILE"

# %%
contador = 6  # Inicializa o contador em 0

while contador < 10:  # Inicia um loop while que continua enquanto o contador for menor que 10
    print(f"Contador: {contador}")  # Imprime o valor atual do contador
    contador += 1  # Incrementa o contador em 1

    if contador == 5:
        print("Encontrou o número 5! Vamos parar o loop.")
        break

else:
    print("Loop concluído sem interrupções inesperadas.")
    # O bloco else associado ao loop while é executado se o loop for concluído normalmente, sem ser interrompido por um break

print("Fim do programa.")
# Out:
# Contador: 6
# Contador: 7
# Contador: 8
# Contador: 9
# Loop concluído sem interrupções inesperadas.
# Fim do programa.

# %% [markdown]
# ## Laços de repetição (for)
#
# Na última aula, vimos como usar o laço de repetição "while" para repetir operações em Python
#
# Agora, veremos um outro laço, o **for**
#
# Mas, antes de vermos como este laço pode ser utilizado para **repetir operações**, é interessante entender o `for` como sendo, na realidade, um operador utilizado para **percorrer elementos de uma lista** (na verdade, de qualquer objeto **iterável**. Conheceremos outros objetos assim mais pra frente...)
#
# A estrutura do for é:
#
# ```python
# for item in lista:
#     operacao_feita_pra_cada_item
# ```

# %%
lista = ["a", "b", "c", "d"]

for item in lista:
    print(item)
# Out:
# a
# b
# c
# d

# %% [markdown]
# O código acima é equivalente a:

# %%
lista = ["a", "b", "c", "d"]

print(lista[0])
print(lista[1])
print(lista[2])
print(lista[3])
# Out:
# a
# b
# c
# d

# %% [markdown]
# Separando os valores de uma lista em duas listas distintas:

# %%
# Criando uma lista de números
lista = [4, 5, 6, 5, -6, 56, 7, -10, 78, 80, 9]

# Inicializando listas vazias para armazenar números negativos e positivos
lista_neg = []
lista_pos = []

# Iterando sobre cada elemento da lista
for x in lista:
    # Verificando se o elemento é negativo
    if x < 0:
        # Se for negativo, adiciona à lista_neg
        lista_neg.append(x)
    else:
        # Se for não negativo, adiciona à lista_pos
        lista_pos.append(x)

# Imprimindo as listas resultantes
print("Números positivos:", lista_pos)
print("Números negativos:", lista_neg)
# Out:
# Números positivos: [4, 5, 6, 5, 56, 7, 78, 80, 9]
# Números negativos: [-6, -10]

# %% [markdown]
# Podemos fazer operações com os elementos de umas lista e usá-los pra preencher outra lista:

# %%
# Criando uma lista de números
lista = [1, 2, 3, 5, 153, -56]

# Inicializando uma lista vazia para armazenar o dobro de cada elemento
lista_dobro = []

# Iterando sobre cada elemento da lista
for elemento in lista:
    # Multiplicando cada elemento por 2 e adicionando à lista_dobro
    lista_dobro.append(2 * elemento)

# Imprimindo a lista resultante
print("Lista com o dobro de cada elemento:", lista_dobro)
# Out:
# Lista com o dobro de cada elemento: [2, 4, 6, 10, 306, -112]

# %% [markdown]
# ### Função Range()

# %%
for elemento in range(5):
    print("Olá, mundo")
# Out:
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo
# Olá, mundo

# %% [markdown]
# É muito comum utilizarmos a função "range()" juntamente do for
#
# Essa função cria um **intervalo**, que é uma espécie de "lista virtual" de **números em sequência**. Sua sintaxe é:
#
# - range(primeiro_numero, último_numero - 1, passo)
#
# Se for dado apenas um argumento, o padrão é começar por zero, e ir de 1 em 1:
#
# - range(10) é equivalente a range(0, 10, 1), cria uma sequência de 0 a 9, de 1 em 1
# - range(-12, 12, 2): cria uma sequência de -12 a 11, de 2 em 2
#
# Ao fazermos list(range()), obtermos uma lista correspondente ao iterável.
#
# **OBS: só podemos fazer iteráveis de int!**

# %% [markdown]
# O range é muito interessante caso **queiramos repetir determinada instrução**
#
# Se vc quer repetir N vezes, basta fazer:
#
# ```python
# for i in range(N):
#     operacao_repetida
# ```
#
# É neste sentido que o `for` passa a ser explicitamente um laço de repetição!
#
# Mas note que este laço se diferencia do while no fato de **não precisar de uma condição explícita**
#
# Este laço determina que as operações sejam repetidas **para valores em uma lista** (que no caso é o `range`).
#
# Este laço é, portanto, bem mais controlado -- dificilmente ocorrerá loops infinitos!

# %% [markdown]
# É muito comum usar o for com o range para **percorrer os índices de uma lista**, e assim também **acessar os elementos da lista através do índice**.
#
# Isso é feito passando pro range o comprinento da lista como argumento!

# %%
# Criando uma lista mista de caracteres e números
lista = ["a", "b", "c", "d", 1, 2, 5, 6]

# Iterando sobre a lista usando índices e verificando se o índice é par
for i in range(0, len(lista), 1):
    if i % 2 == 0:
        # Imprimindo o índice e o elemento correspondente quando o índice é par
        print(i, lista[i])
# Out:
# 0 a
# 2 c
# 4 1
# 6 5

# %% [markdown]
# ## Funções
#
# Até o momento, já vimos diversas funções em Python.
#
# - Na primeira aula, tivemos contato com a função `print()`, que exibe um texto na tela;
#
# - Depois, aprendemos sobre a função `input()`, que serve pra capturar algo que o usuário digita;

# %%
print("Olá")
# Out:
# Olá

# %%
variavel = input("digite algo: ")
# Out:
# digite algo: algo

# %%
max([1, 2, 3])
# Out:
# 3

# %%
"python".lower()
# Out:
# 'python'

# %% [markdown]
# A intuição sobre funções, então, já nos é familiar:
#
# Uma função é um objeto utilizado para **fazer determinadas ações**.
#
# Podemos ver uma função como uma "caixinha" que pega uma **entrada** (o argumento), faz algum **processamento**, e então **retorna uma saída** (o output)
#
# <img src="https://s3.amazonaws.com/illustrativemathematics/images/000/000/782/medium/Task_1_8c7a6a9a2e1421586c40f125bd783de3.jpg?1335065782" width=300>
#
#
# <img src="https://1.bp.blogspot.com/_MhOt9n2UJbM/TC6emeqHdqI/AAAAAAAAAiQ/1brsWuWvOC0/s1600/function-machine.png" width=300>

# %% [markdown]
# Aprenderemos agora como criar **nossas próprias funções** em Python!

# %% [markdown]
# A estrutura de **definição de uma função** é dada por:
#
# ```python
# def nome_da_funcao(argumentos):
#
#     instrucoes
#
#     return saida
# ```

# %% [markdown]
# Há 5 elementos fundamentais para a criação de novas funções em Python:
#
# - Primeiramente, usamos "def" para deixar claro que estamos **definindo** uma função;
# - Depois, damos um **nome** para nossa função;
# - Em parênteses, falamos quais serão os **argumentos** da função -- esses são os inputs, e em python, esses elementos são opcionais!
# - Depois, explicitamos qual é o **processamento** feito pela função;
# - Ao fim, dizemos o que a função irá **retornar** -- esses são os outputs, e em Python esse elemento é opcional!

# %% [markdown]
# Sempre que quisermos **executar** uma função, basta **chamá-la**, dando os argumentos desejados!
#
# ```python
# nome_da_funcao(argumentos)
# ```

# %% [markdown]
# __Uma função sem argumentos e sem return__
#
# Apenas imprime algo na tela, mas sempre A MESMA COISA

# %%
def cumprimenta():

    print("Olá!")

# %% [markdown]
# __Chamando a função__

# %%
cumprimenta()
# Out:
# Olá!

# %% [markdown]
# __Uma função com argumento, mas sem return__
#
# Imprime o que eu mandar na tela, como argumento!

# %%
def cumprimenta(nome):

    print("Olá,", nome)

# %%
cumprimenta("João")
# Out:
# Olá, João

# %% [markdown]
# __Uma função com dois argumentos, mas ainda sem return__
#
# Imprime algo na tela, mas dependendo do segundo argumento que eu passar

# %%
def cumprimenta_horario(nome, hora):

    if hora < 12:
        print("Bom dia,", nome)

    elif hora < 19:
        print("Boa tarde,", nome)

    else:
        print("Boa noite,", nome)

# %%
cumprimenta_horario(nome = "André", hora = 14)
# Out:
# Boa tarde, André

# %% [markdown]
# __Mas e o return?__
#
#
# Todas as funções acima de fato fazem alguma operação, mas nõs não conseguimos **acessar** o resultado das operações! Veja um exemplo mais claro: uma função que calcula a soma de dois números:

# %%
def calc_soma(n1, n2):

    soma = n1 + n2

    print(soma)

# %%
calc_soma(10, 32)
# Out:
# 42

# %% [markdown]
# Note que a função calcula a soma dos números, mas apenas exibe este resultado com o print!
#
# **A variável "soma" é uma variável que existe apenas no interior da função!!**

# %%
soma
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-265-ac2450a231f3> in <cell line: 1>()
# ----> 1 soma
#
# NameError: name 'soma' is not defined

# %% [markdown]
# Se quisermos armazenar o valor da soma, podemos **retornar** o valor desta variável!
#
# **OBS.:** apenas o **valor** da variável é retornado, não o nome dela!!
#
# Fora da função, o nome de variável "soma" ainda continua não existindo!!

# %%
def calc_soma(n1, n2):

    soma = n1 + n2

    return soma

# %%
calc_soma(2, 4)
# Out:
# 6

# %% [markdown]
# Daí, basta armazenar o resultado retornado em uma variável, **como fazíamos com o input()!**

# %%
resultado = calc_soma(2, 4)

resultado
# Out:
# 6

# %% [markdown]
# ## 1) Strings
#
# Desde a primeira aula, temos trabalhado com strings, que, como vimos, representam **dados textuais**
#
# Vamos, agora, olhar pra strings um pouco mais a fundo, e aprender algumas funções para trabalharmos com strings

# %% [markdown]
# Uma string nada mais é do que uma **coleção de caracteres**!
#
# Assim, podemos acessar caracteres específicos ou então um intervalo de caracteres de uma string, como se fosse uma lista!
#
# **OBS.: Para strings também, o índice começa em 0, e podemos usar índices negativos!**

# %% [markdown]
# 1. Criando Strings

# %%
string1 = "Olá, mundo!"
string1
# Out:
# 'Olá, mundo!'

# %%
string2 = 'Python é incrível!'
string2
# Out:
# 'Python é incrível!'

# %%
string3 = """Strings em Python
podem ser multilineares."""
string3
# Out:
# 'Strings em Python\npodem ser multilineares.'

# %%
string4 = 'Concatenando ' + 'strings'
string4
# Out:
# 'Concatenando strings'

# %% [markdown]
# 2. Acessando caracteres em uma string

# %%
string1
# Out:
# 'Olá, mundo!'

# %%
print(string1)
# Out:
# Olá, mundo!

# %%
print(string2)
# Out:
# Python é incrível!

# %%
# Primeiro caracter da string 1
primeiro_caracter = string1[0]

# Ultimo caracter da string 2
ultimo_caracter = string2[-1]

print("2. Acessando caracteres em uma string:")
print(primeiro_caracter)
print(ultimo_caracter)
# Out:
# 2. Acessando caracteres em uma string:
# O
# !

# %% [markdown]
# 3. Comprimento da string

# %%
print(string3)
# Out:
# Strings em Python
# podem ser multilineares.

# %%
tamanho = len(string3)

print("3. Comprimento da string:")
print(tamanho)
# Out:
# 3. Comprimento da string:
# 42

# %% [markdown]
# 4. Iterando sobre uma string

# %%
print(string4)
# Out:
# Concatenando strings

# %%
print("4. Iterando sobre uma string:")
for char in string4:
    print(char, end=' ')
# Out:
# 4. Iterando sobre uma string:
# C o n c a t e n a n d o   s t r i n g s

# %% [markdown]
#  5. Métodos de String

# %%
maiusculas = string1.upper()
minusculas = string2.lower()
capitalizada = string3.capitalize()
titulo = string4.title()


print("5. Métodos de String:")
print()
print(f'5.1 >>> {maiusculas}')
print()
print(f'5.2 >>> {minusculas}')
print()
print(f'5.3 >>> {capitalizada}')
print()
print(f'5.4 >>> {titulo}')
# Out:
# 5. Métodos de String:
#
# 5.1 >>> OLÁ, MUNDO!
#
# 5.2 >>> python é incrível!
#
# 5.3 >>> Strings em python
# podem ser multilineares.
#
# 5.4 >>> Concatenando Strings

# %% [markdown]
# 6. Busca em Strings

# %%
print(string3)
# Out:
# Strings em Python
# podem ser multilineares.

# %%
achou = 'Python' in string2
indice = string3.find('Python')
print("6. Busca em Strings:")

print(indice)
print(achou)
# Out:
# 6. Busca em Strings:
# 11
# True

# %% [markdown]
# 7. Formatação de Strings

# %%
nome = 'Alice'
idade = 25
ponto_format = "Olá, meu nome é {} e tenho {} anos.".format(nome, idade)
f_string = f"Olá, meu nome é {nome} e tenho {idade} anos."

print("7. Formatação de Strings:")
print(ponto_format)
print(f_string)
# Out:
# 7. Formatação de Strings:
# Olá, meu nome é Alice e tenho 25 anos.
# Olá, meu nome é Alice e tenho 25 anos.

# %% [markdown]
# 8. Quebrando e juntando strings

# %%
print(string3)
# Out:
# Strings em Python
# podem ser multilineares.

# %%
palavras = string3.split()

print("8. Quebrando strings:")
print(palavras)
# Out:
# 8. Quebrando strings:
# ['Strings', 'em', 'Python', 'podem', 'ser', 'multilineares.']

# %%
frase_nova = ' '.join(palavras)

print("8. Juntando strings:")
print(frase_nova)
# Out:
# 8. Juntando strings:
# Strings em Python podem ser multilineares.

# %% [markdown]
# 9. Strip e Replace

# %%
espacos = "   Muitos espaços   "
sem_espacos = espacos.strip()

print("9.1. Strip")
print(sem_espacos)
# Out:
# 9.1. Strip
# Muitos espaços

# %% [markdown]
# Será que os espaços foram ealmente retirados?

# %%
espacos = "   Muitos espaços   "
sem_espacos = espacos.strip()

# Contagem antes da formatação
antes = len(espacos)

# Contagem após a formatação
depois = len(sem_espacos)

print("9.1. Strip:")
print(f"Antes da formatação: {antes} caracteres")
print(f"Depois da formatação: {depois} caracteres")
# Out:
# 9.1. Strip:
# Antes da formatação: 20 caracteres
# Depois da formatação: 14 caracteres

# %%
trocar_espacos = espacos.replace(' ', '_')

print("9.2.. Replace:")
print(trocar_espacos)
# Out:
# 9.2.. Replace:
# ___Muitos_espaços___

# %% [markdown]
# 10. Comparando Strings

# %%
print(string1)
# Out:
# Olá, mundo!

# %%
print(string2)
# Out:
# Python é incrível!

# %%
comparacao = (string1 == string2)

print("10. Comparando Strings:")
print(comparacao)
# Out:
# 10. Comparando Strings:
# False

# %% [markdown]
# 11. Fatiamento (slicing) de Strings

# %%
print(string3)
# Out:
# Strings em Python
# podem ser multilineares.

# %%
substring = string3[3:6]

print("11. Fatiamento (slicing) de Strings:")
print(substring)
# Out:
# 11. Fatiamento (slicing) de Strings:
# ing

# %% [markdown]
# ## Na próxima aula, vamos falar sobre bibliotecas, mas vou dar um spoiler em relação há strings!

# %%
# Instalar bibliotecas quando necessário!

# %%
# !pip install unidecode==1.3.8
# Out:
# Requirement already satisfied: unidecode==1.3.8 in /usr/local/lib/python3.10/dist-packages (1.3.8)

# %%
# Importando bibliotecas
from unidecode import unidecode
import re

# %% [markdown]
# 12. Removendo acentos com unidecode

# %%
texto_acentuado = "Coração"
texto_sem_acentos = unidecode(texto_acentuado)

# Exibindo resultados
print("\n12. Removendo acentos com unidecode:")
print(f"Original: {texto_acentuado}\nSem Acentos: {texto_sem_acentos}")
# Out:
# 12. Removendo acentos com unidecode:
# Original: Coração
# Sem Acentos: Coracao

# %% [markdown]
# 13. Expressões Regulares (Regex)

# %%
padrao = r'\b[A-Za-z]+\b'  # Encontrar palavras
texto_com_numeros = "123 Python 456 Java 789"
palavras_encontradas = re.findall(padrao, texto_com_numeros)

print("\n13. Expressões Regulares (Regex):")
print(f"Texto com números: {texto_com_numeros}")
print(f"Palavras encontradas: {palavras_encontradas}")
# Out:
# 13. Expressões Regulares (Regex):
# Texto com números: 123 Python 456 Java 789
# Palavras encontradas: ['Python', 'Java']

# %%
# Imprimir como uma string
resultado = ' '.join(palavras_encontradas)
print(resultado)
# Out:
# Python Java

# %% [markdown]
# regEx:
#
# Sites:
#
#     https://regexr.com/
#
#
#     https://regex101.com/
#
#
#     https://www.regextester.com/104210
#
# IA Gen:
#
#     ChatGPT
#
#     Gemini
#
#     MariTalk
